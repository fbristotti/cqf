# %%
import numpy as np
import pandas as pd

# Visualizaiton
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# Data Preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.pipeline import Pipeline

# Regressor
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet

# Metrics
from sklearn.metrics import mean_squared_error

# set display options
pd.options.display.float_format = "{:,.2f}".format

# Machine info & package version
from watermark import watermark
# %load_ext watermark
# %watermark -a "Fernando Bristotti" -u -d -v -m -iv

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')
# Out:
# The watermark extension is already loaded. To reload it, use:
#   %reload_ext watermark
# Author: Fernando Bristotti
#
# Last updated: 2023-05-08
#
# Python implementation: CPython
# Python version       : 3.10.6
# IPython version      : 8.4.0
#
# Compiler    : MSC v.1916 64 bit (AMD64)
# OS          : Windows
# Release     : 10
# Machine     : AMD64
# Processor   : Intel64 Family 6 Model 140 Stepping 1, GenuineIntel
# CPU cores   : 8
# Architecture: 64bit
#
# numpy     : 1.23.1
# pandas    : 1.4.4
# seaborn   : 0.12.0
# matplotlib: 3.5.2

# %% [markdown]
# ## Load Data

# %%
# load nifty index data
df = pd.read_csv('https://raw.githubusercontent.com/kannansingaravelu/datasets/main/niftyindex.csv', 
                 index_col=0, 
                 dayfirst=True)
df
# Out:
#                 Open      High       Low     Close     Volume
# 02/01/2012  4,640.20  4,645.95  4,588.05  4,636.75  108461000
# 03/01/2012  4,675.80  4,773.10  4,675.80  4,765.30  146621008
# 04/01/2012  4,774.95  4,782.85  4,728.85  4,749.65  165939008
# 05/01/2012  4,749.00  4,779.80  4,730.15  4,749.95  177863008
# 06/01/2012  4,724.15  4,794.90  4,686.85  4,754.10  176057008
# ...              ...       ...       ...       ...        ...
# 26/12/2022 17,830.40 18,084.10 17,774.25 18,014.60  176652336
# 27/12/2022 18,089.80 18,149.25 17,967.45 18,132.30  214257088
# 28/12/2022 18,084.75 18,173.10 18,068.35 18,122.50  193873168
# 29/12/2022 18,045.70 18,229.70 17,992.80 18,191.00  281052832
# 30/12/2022 18,259.10 18,265.25 18,080.30 18,105.30  192005568
#
# [2719 rows x 5 columns]

# %%
df.describe()
# Out:
#            Open      High       Low     Close           Volume
# count  2,719.00  2,719.00  2,719.00  2,719.00         2,719.00
# mean  10,124.90 10,175.29 10,057.47 10,117.57   289,222,065.64
# std    3,709.61  3,725.53  3,685.31  3,706.95   195,276,778.85
# min    4,640.20  4,645.95  4,588.05  4,636.75     2,826,000.00
# 25%    7,637.00  7,681.00  7,581.65  7,623.80   159,178,008.00
# 50%    9,376.95  9,431.90  9,301.35  9,351.85   219,496,064.00
# 75%   11,700.85 11,755.12 11,631.33 11,684.00   340,908,832.00
# max   18,871.95 18,887.60 18,778.20 18,812.50 1,810,971,008.00

# %%
df.isnull().sum()
# Out:
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %% [markdown]
# ## Feature Specification

# %%
# create features
def create_features(frame):
    df = frame.copy()
    multiplier = 2

    # spy features
    df['OC'] = df['Close'] / df['Open'] - 1
    df['HC'] = df['High'] / df['Low'] - 1
    df['GAP'] = df['Open'] / df['Close'].shift(1) - 1
    df['RET'] = np.log(df['Close'] / df['Close'].shift(1))

    for i in [3]:
        df['RET' + str(i)] = df['RET'].rolling(i).sum()
        df['MA' + str(i)] = df['Close'] / df['Close'].rolling(i).mean() 
        df['OC'+ str(i)] = df['OC'].rolling(i).mean() 
        df['HC'+ str(i)] = df['HC'].rolling(i).mean() 
        df['GAP'+ str(i)] = df['GAP'].rolling(i).mean()
        df['STD'+ str(i)] = df['RET'].rolling(i).std()
        df['UB'+str(i)] = df['Close'].rolling(i).mean() + df['Close'].rolling(i).std() * multiplier
        df['LB'+str(i)] = df['Close'].rolling(i).mean() - df['Close'].rolling(i).std() * multiplier
    
    df['Label'] = df['Close'].shift(-1)
    
    # drop NaN values
    df.dropna(inplace=True)
    return df

# %%
# features
df = create_features(df)
display(df.shape)
# Out:
# (2715, 18)

# %%
# drop OHLCV and Labels 
X = df.drop(['Open', 'High', 'Low', 'Close', 'Volume', 'Label'], axis=1)
X
# Out:
#               OC   HC   GAP   RET  RET3  MA3   OC3  HC3  GAP3  STD3       UB3  \
# 05/01/2012  0.00 0.01 -0.00  0.00  0.02 1.00  0.00 0.01  0.00  0.02  4,772.87
# 06/01/2012  0.01 0.02 -0.01  0.00 -0.00 1.00  0.00 0.01 -0.00  0.00  4,756.21
# 09/01/2012 -0.00 0.01 -0.00 -0.00 -0.00 1.00  0.00 0.02 -0.00  0.00  4,760.38
# 10/01/2012  0.02 0.02  0.01  0.02  0.02 1.01  0.01 0.02 -0.00  0.01  4,899.44
# 11/01/2012 -0.00 0.01  0.00  0.00  0.02 1.01  0.00 0.01  0.00  0.01  4,948.11
# ...          ...  ...   ...   ...   ...  ...   ...  ...   ...   ...       ...
# 23/12/2022 -0.01 0.02 -0.01 -0.02 -0.03 0.99 -0.01 0.02 -0.00  0.01 18,462.19
# 26/12/2022  0.01 0.02  0.00  0.01 -0.01 1.00 -0.00 0.02 -0.00  0.01 18,308.13
# 27/12/2022  0.00 0.01  0.00  0.01  0.00 1.01  0.00 0.01 -0.00  0.02 18,314.20
# 28/12/2022  0.00 0.01 -0.00 -0.00  0.02 1.00  0.00 0.01  0.00  0.01 18,220.42
# 29/12/2022  0.01 0.01 -0.00  0.00  0.01 1.00  0.00 0.01 -0.00  0.00 18,222.69
#
#                  LB3
# 05/01/2012  4,737.07
# 06/01/2012  4,746.26
# 09/01/2012  4,737.52
# 10/01/2012  4,664.86
# 11/01/2012  4,687.42
# ...              ...
# 23/12/2022 17,626.65
# 26/12/2022 17,657.70
# 27/12/2022 17,654.94
# 28/12/2022 17,959.18
# 29/12/2022 18,074.51
#
# [2715 rows x 12 columns]

# %%
# label 
y = np.array(df['Label'])
y
# Out:
# array([ 4754.1 ,  4742.8 ,  4849.55, ..., 18122.5 , 18191.  , 18105.3 ])

# %% [markdown]
# ## Feature selection

# %% [markdown]
# Reduce the number of input variables that are believed to be most useful to a model. We use correlation measures which is one othe filter methods do address multicollinearity among features.

# %%
# remove features that are highly correlated
sns.set(rc={'figure.figsize': (20, 10)})

sns.heatmap(X.corr()>0.9, #X.corr()
            annot=True,  
            annot_kws={"size": 11}, 
            fmt=".2f", 
            linewidth=.5, 
            cmap="coolwarm", 
            cbar=True); #cmap="crest", virids, magma

plt.title('Features Set Correlations');

# %%
# drop the highly correlated features
to_drop = ['LB3']
X.drop(to_drop, axis=1, inplace=True)

# record feature names
feature_names = X.columns

# display the features set 
X
# Out:
#               OC   HC   GAP   RET  RET3  MA3   OC3  HC3  GAP3  STD3       UB3
# 05/01/2012  0.00 0.01 -0.00  0.00  0.02 1.00  0.00 0.01  0.00  0.02  4,772.87
# 06/01/2012  0.01 0.02 -0.01  0.00 -0.00 1.00  0.00 0.01 -0.00  0.00  4,756.21
# 09/01/2012 -0.00 0.01 -0.00 -0.00 -0.00 1.00  0.00 0.02 -0.00  0.00  4,760.38
# 10/01/2012  0.02 0.02  0.01  0.02  0.02 1.01  0.01 0.02 -0.00  0.01  4,899.44
# 11/01/2012 -0.00 0.01  0.00  0.00  0.02 1.01  0.00 0.01  0.00  0.01  4,948.11
# ...          ...  ...   ...   ...   ...  ...   ...  ...   ...   ...       ...
# 23/12/2022 -0.01 0.02 -0.01 -0.02 -0.03 0.99 -0.01 0.02 -0.00  0.01 18,462.19
# 26/12/2022  0.01 0.02  0.00  0.01 -0.01 1.00 -0.00 0.02 -0.00  0.01 18,308.13
# 27/12/2022  0.00 0.01  0.00  0.01  0.00 1.01  0.00 0.01 -0.00  0.02 18,314.20
# 28/12/2022  0.00 0.01 -0.00 -0.00  0.02 1.00  0.00 0.01  0.00  0.01 18,220.42
# 29/12/2022  0.01 0.01 -0.00  0.00  0.01 1.00  0.00 0.01 -0.00  0.00 18,222.69
#
# [2715 rows x 11 columns]

# %% [markdown]
# ## EDA fo Feature Scaling

# %% [markdown]
# The choice of scaling techiniques to be used should come form the Exploratory Data Analysis of features set.

# %%
X.describe()
# Out:
#             OC       HC      GAP      RET     RET3      MA3      OC3      HC3  \
# count 2,715.00 2,715.00 2,715.00 2,715.00 2,715.00 2,715.00 2,715.00 2,715.00
# mean     -0.00     0.01     0.00     0.00     0.00     1.00    -0.00     0.01
# std       0.01     0.01     0.01     0.01     0.02     0.01     0.00     0.01
# min      -0.07     0.00    -0.09    -0.14    -0.16     0.93    -0.05     0.00
# 25%      -0.01     0.01    -0.00    -0.00    -0.01     1.00    -0.00     0.01
# 50%      -0.00     0.01     0.00     0.00     0.00     1.00    -0.00     0.01
# 75%       0.00     0.01     0.00     0.01     0.01     1.01     0.00     0.01
# max       0.09     0.19     0.04     0.08     0.13     1.05     0.03     0.10
#
#           GAP3     STD3       UB3
# count 2,715.00 2,715.00  2,715.00
# mean      0.00     0.01 10,252.58
# std       0.00     0.01  3,749.88
# min      -0.05     0.00  4,756.21
# 25%      -0.00     0.00  7,748.51
# 50%       0.00     0.01  9,496.35
# 75%       0.00     0.01 11,846.27
# max       0.02     0.11 18,930.34

# %%
# study the distribution in df
sns.boxplot(x='variable',y='value', data=pd.melt(df))
plt.xlabel(''); plt.ylabel('')
plt.title('Exploratory Data Analysis')
# Out:
# Text(0.5, 1.0, 'Exploratory Data Analysis')

# %%
# study the distribution in X
sns.boxplot(x='variable',y='value', data=pd.melt(X))
plt.xlabel(''); plt.ylabel('')
plt.title('Exploratory Data Analysis')
# Out:
# Text(0.5, 1.0, 'Exploratory Data Analysis')

# %% [markdown]
# ## Regression Class

# %% [markdown]
# We'll now create a Regression class fo linear estimators: Linear, Lasso, Ridge and ElasticNet

# %%
class Regression:
    def __init__(self, X, y, testsize=0.20):

        self.X = X
        self.y = y
        self.testsize = testsize
        
        # split training and testing dataset
        self.X_train, self.X_test, self.y_train, self.y_test = train_test_split(self.X, 
                                                                                self.y, 
                                                                                test_size=self.testsize, 
                                                                                random_state=0, 
                                                                                shuffle=False)
    
    # fit and predict
    def fit_predict(self, estimator, transformer, alpha=None, l1_ratio=None):
        
        try:
            # subsume estimators and transformer into a pipeline
            model = Pipeline([
            ('scaler', transformer), 
            ('regressor', estimator)
            ])

            # fit/train model
            model.fit(self.X_train, self.y_train)

            # predict lables
            y_pred = model.predict(self.X_test)

        except Exception as e:
            print(str(e))

        return model, model['regressor'].intercept_, model['regressor'].coef_, y_pred

    # evaluate metrics
    def eval_metrics(self,model, y_pred):

        # evaluate metrics
        mse = mean_squared_error(self.y_test, y_pred, squared=True)
        rmse = mean_squared_error(self.y_test, y_pred, squared=False)
        r2train = model.score(self.X_train, self.y_train)
        r2test = model.score(self.X_test, self.y_test)

        return mse, rmse, r2train, r2test

    # plot coefficients as a function of lambda
    def plot_coeff(self, modelname):

        coef = []
        model = Regression(self.X, self.y, 0.20)
        alpha_range = np.logspace(2, -2, 200)

        if modelname == 'Lasso':
            for i in alpha_range:    
                coef.append(model.fit_predict(Lasso(alpha=i, random_state=0), MinMaxScaler())[2])

        elif modelname == 'Ridge':
            alpha_range = np.logspace(6, -2, 200)
            for i in alpha_range:    
                coef.append(model.fit_predict(Ridge(alpha=i, random_state=0), MinMaxScaler())[2])

        elif modelname == 'ElasticNet':
            for i in alpha_range:    
                coef.append(model.fit_predict(ElasticNet(alpha=i, random_state=0), MinMaxScaler())[2])
        
        # Plot Coefficients
        fig = plt.figure(figsize=(20,8))
        ax = plt.axes()
        
        ax.plot(alpha_range, coef)
        ax.set_xscale('log')
        ax.legend(feature_names, loc=0)
        # ax.set_xlim(ax.get_xlim()[::-1])  # reverse axis
        ax.set_title(f'{modelname} coefficients as a function of the regularization')
        ax.set_xlabel('$\lambda$')
        ax.set_ylabel('$\mathbf{w}$')

        return plt.show()

# %% [markdown]
# ### Linear Regression

# %%
# instantiate 
lr = Regression(X, y)

# fit Linear Regression
lr_model , lr_intercept, lr_coef, lr_y_pred = lr.fit_predict(LinearRegression(), MinMaxScaler())
lr_model , lr_intercept, lr_coef, lr_y_pred
# Out:
# (Pipeline(steps=[('scaler', MinMaxScaler()), ('regressor', LinearRegression())]),
#  6733.034609811644,
#  array([-8811.45765281,  -226.80443673, -7788.61654093, 12335.03547994,
#          3312.30633735,  1058.61701543, -2879.451858  ,  -481.03024078,
#         -2013.17004147,  -339.5891121 ,  7604.80005646]),
#  array([11834.07902708, 11796.86075804, 11881.80945993, 11694.6500994 ,
#         11747.33476593, 11561.81608289, 11527.75762447, 11809.38175021,
#         11966.35608659, 12216.52513596, 12410.52457194, 12606.53742737,
#         12788.07550626, 12838.24424523, 12639.93958793, 12613.11245462,
#         12702.64950025, 12857.36110898, 12965.51842609, 12791.69123998,
#         12820.65283429, 12856.03255769, 13079.34969667, 12867.27465481,
#         12972.52865026, 12904.6456969 , 13049.43680271, 13105.34830695,
#         12998.47407834, 13241.67727711, 13401.15491653, 13354.59970031,
#         13521.99543715, 13465.65413446, 13394.87919171, 13464.93936999,
#         13473.37868938, 13642.30670983, 13745.24203708, 13694.79966071,
#         13576.91153758, 13620.28846932, 13511.73887887, 13784.59521481,
#         16302.7825095 , 16369.21062938, 16067.05976977, 15542.73533917,
#         15547.48386744, 15564.33279427, 15166.65193363, 15647.43815042,
#         15491.33429397, 15501.48241159, 15681.90413687, 15851.47128265,
#         15827.12858011, 15679.33316884, 15651.83924161, 15588.8574379 ,
#         15677.49278843, 15646.66760167, 15905.34152066, 16168.98034483,
#         16210.58680567, 16142.70947599, 16104.68833698, 16056.05985114,
#         15890.81952342, 15944.43497289, 16327.80892679, 16393.56615896,
#         16484.7455651 , 16628.89778413, 16692.03432662, 16559.47990273,
#         16568.07082063, 16563.41728808, 16999.17647141, 17318.16949251,
#         17435.61531901, 17310.6882103 , 17201.90019065, 17182.60623887,
#         17202.57949616, 17417.80093051, 17457.57469619, 17555.70876759,
#         17658.13954251, 17771.00648634, 17932.99468613, 17887.0006789 ,
#         17793.45018011, 17839.76809147, 17602.64357339, 17439.61169116,
#         17363.84722835, 17428.91682292, 17431.20978165, 17743.22258313,
#         17633.61934729, 17504.31132999, 17515.31324278, 17564.01019164,
#         17466.41161369, 17697.64979611, 17787.51625779, 17856.38367046,
#         18061.44874141, 17906.18708866, 17852.53223034, 17854.835044  ,
#         17745.05288542, 17740.32512931, 17680.63619335, 17635.20757609,
#         17581.83304002, 17531.26621277, 17158.73669137, 16852.1913172 ,
#         16815.82308372, 17006.45510442, 16900.61496921, 17243.27699576,
#         17489.74869277, 17167.93659698, 17162.70621565, 17148.2135358 ,
#         17106.87987657, 16940.2094073 , 17068.84908956, 17325.57717505,
#         17515.975009  , 17476.19616353, 17431.58530698, 17427.78377104,
#         17649.56284237, 17609.50760121, 17621.1129023 , 17701.71467498,
#         18013.32121931, 18213.25015333, 18006.89405381, 17971.47446724,
#         17955.18394041, 18078.65785642, 18024.95775931, 18059.09570065,
#         18331.17400996, 18413.48003879, 18248.71779768, 18291.55825875,
#         18238.36367564, 18225.55114106, 18210.08498409, 18173.34905833,
#         18145.61473631, 18440.96834118, 18518.15042647, 18378.68235664,
#         18479.01696954, 18650.84797181, 18741.43420865, 18621.76598029,
#         18643.32768001, 18528.07017871, 18531.73942232, 18483.91820249,
#         18410.15717499, 18429.60306702, 18460.88226914, 18571.14978958,
#         18505.8586406 , 18530.56585877, 18302.24238166, 18277.55934409,
#         18223.77507166, 18197.91059816, 18105.38576252, 18030.45049532,
#         18086.30129733, 18002.45206318, 18015.88793338]))

# %% [markdown]
# ## Regularized Regression

# %% [markdown]
# IF the coeficients are too large in linear regression, it can lead to overfitting the model. We do regularization to over come such issues that penalises large coefficients. Lasso and Ridge regression are penalty regression that prevent over-fitting from the simple linear regression.

# %% [markdown]
# ### LASSO

# %% [markdown]
# The Least Absolute Shrinkage and Selection Operator (LASSO) is a variation of linear regression. In LASSO, the loss function is minimized by limiting the sum of absolute values of the model coefficients where the L1 penalty term is added to the Mean Square Error (MSE). The L1 penalty term not only shrinks the coefficents, bu shrinks some of them to zero and that is very useful for feature selection.
#
# $$
# L = \frac{1}{n} \sum_{i=1}^{n} \left( y_i - w_0 - \sum_{j=1}^{p} x_{ij}w_j \right)^2 + \lambda \sum_{j=1}^{p} |w_j|
#         17947.52245503, 18081.03888777, 18024.49217741, 18039.80848862,
#         18332.78707898, 18402.53840151, 18242.8737744 , 18281.92543359,
#         18232.22382417, 18225.74669056, 18200.6755238 , 18160.75698512,
#         18141.86956197, 18432.24125847, 18509.10905082, 18367.44230504,
#         18471.86196913, 18645.05021499, 18744.57272719, 18613.36224959,
#         18635.18678044, 18513.95308567, 18531.58881492, 18479.2420281 ,
#         18408.67645698, 18411.83315885, 18445.51967447, 18571.76868352,
#         18507.02603428, 18517.00573134, 18281.54293819, 18262.29901995,
#         18233.82185082, 18191.53981397, 18077.24511223, 18006.73506074,
#         18066.97836955, 17992.06192948, 18005.10074236]))

# %%
# plot coefficients
lasso.plot_coeff('Lasso')

# %% [markdown]
# ### Ridge

# %% [markdown]
# In ridge regression, the cost function is altered by adding a L2 penality equivalent to square of the magnitude of the coefficients. The Ridge regression shrinks the coefficients and helps to reduce the multi-collinearity. As seen from the above graph, where $\lambda \to 0$, the cost function becomes similar to the linear regression cost function.
#
# $$
# L = \frac{1}{n} \sum_{i=1}^{n} \left( y_i - w_0 - \sum_{j=1}^{p} x_{ij}w_j \right)^2 + \lambda \sum_{j=1}^{p} w_j^2
# $$

# %%
# instantiate 
ridge = Regression(X,y)

# fit Ridge 
ridge_model , ridge_intercept, ridge_coef, ridge_y_pred = ridge.fit_predict(Ridge(alpha=1, random_state=0), StandardScaler())
ridge_model , ridge_intercept, ridge_coef, ridge_y_pred
# Out:
# (Pipeline(steps=[('scaler', StandardScaler()),
#                  ('regressor', Ridge(alpha=1, random_state=0))]),
#  8577.538858195212,
#  array([ -66.22807928,  -17.94110192,  -60.24200977,   88.59274746,
#           67.63867793,   66.06707152,  -65.61434782,  -39.08763792,
#          -24.70005904,  -25.67001916, 2116.85816033]),
#  array([11836.27671528, 11788.35652903, 11874.8830068 , 11684.68813793,
#         11738.76932903, 11549.10802749, 11519.77440238, 11807.20326973,
#         11958.62906577, 12221.71545808, 12406.11596162, 12613.13812506,
#         12786.37350995, 12832.20757631, 12632.17146457, 12605.59002887,
#         12704.22136065, 12862.17333672, 12965.41252399, 12778.15180698,
#         12810.34986855, 12849.21093031, 13081.01537004, 12862.61187202,
#         12962.73207337, 12898.28594247, 13044.64816766, 13098.19540569,
#         13000.76151452, 13239.79226227, 13398.20233674, 13350.29365908,
#         13521.41070438, 13459.88297266, 13386.63385164, 13460.93742119,
#         13467.82647027, 13643.83238546, 13742.74732304, 13692.6377861 ,
#         13554.46910646, 13601.12162181, 13494.05422925, 13779.92295981,
#         13939.64690855, 13941.49739153, 13923.73006217, 13895.70978925,
#         13922.59954764, 14081.5632391 , 14182.16791626, 14007.67300828,
#         14027.1842859 , 14347.55855127, 14604.00995096, 14575.85224375,
#         14450.70655484, 14443.50331754, 14423.2316287 , 14433.17281037,
#         14474.22240653, 14718.09353988, 14473.11629509, 14488.79087392,
#         14438.84624201, 14245.77030207, 14129.05260391, 13764.83208212,
#         14327.27961463, 15070.35880467, 14844.14008005, 14856.58277966,
#         14833.69083563, 15102.01640408, 15109.95058832, 14924.69424349,
#         17429.06420356, 17300.00665012, 17190.81117253, 17166.87311984,
#         17197.24464389, 17408.28914516, 17450.91938457, 17557.6359433 ,
#         17653.29775533, 17772.01333353, 17927.32441707, 17880.2646006 ,
#         17779.77746602, 17828.41435629, 17587.29749387, 17425.6974543 ,
#         17351.93643522, 17423.6550597 , 17423.86140967, 17727.6843342 ,
#         17608.40317073, 17489.40239583, 17503.27038071, 17554.30654182,
#         17455.63041244, 17692.44078971, 17782.29915817, 17855.24002025,
#         18062.17757618, 17893.73691919, 17840.45402347, 17838.48032577,
#         17730.40728195, 17728.66569524, 17667.84842922, 17621.91101661,
#         17565.54047887, 17518.05853749, 17147.33752266, 16835.92271714,
#         16810.74688658, 16985.05837287, 16885.66740054, 17241.20497133,
#         17482.84303953, 17161.41572963, 17152.46511159, 17134.73447958,
#         17094.66182392, 16928.06625502, 17075.39734348, 17315.25930814,
#         17518.83082687, 17470.57599166, 17424.53310915, 17421.80879399,
#         17650.20284563, 17605.33635626, 17620.43962926, 17697.13588904,
#         18011.18144705, 18209.57591481, 18001.25452154, 17963.19648976,
#         17947.56379489, 18068.73504369, 18019.02882286, 18050.87066943,
#         18332.03659349, 18405.12806909, 18242.41534361, 18285.78504786,
#         18230.95406132, 18217.07157468, 18202.25845826, 18165.8788847 ,
#         18141.09783077, 18431.05851649, 18512.35522603, 18363.99650603,
#         18471.00596051, 18638.4312526 , 18737.03234957, 18611.80772945,
#         18636.53575901, 18520.99219634, 18523.91782591, 18477.82260492,
#         18399.37751249, 18419.21516042, 18452.04413835, 18566.55033678,
#         18491.94095603, 18518.58321662, 18288.83752196, 18260.4323034 ,
#         18209.34655295, 18189.03553756, 18092.17667633, 18012.61755071,
#         18069.31252144, 17993.07947634, 18002.59535805]))

# %%
# plot coefficients
ridge.plot_coeff('Ridge')

# %% [markdown]
# ### ElasticNet Regression

# %% [markdown]
# ElasticNet combines the properties of both LASSO and Ridge regression. It penalizes the model using both the L1 and the L2 norm.
#
# $$
# L = \frac{1}{n} \sum_{i=1}^{n} \left( y_i - w_0 - \sum_{j=1}^{p} x_{ij}w_j \right)^2 + \lambda \left( \frac{1-\alpha}{2} \sum_{j=1}^{p} w_j^2 + \alpha \sum_{j=1}^{p} |w_j| \right)
# $$
#
# where $ 0 \leq \alpha \leq 1$. ElasticNet is same as LASSO where $\alpha = 1$ and Ridge where $\alpha = 0$, For other values of $\alpha$, the penalty term interbolate between L1 an dL2 norm of the coefficients.

# %%
# instantiate 
elasticnet = Regression(X,y)

# fit ElasticNet
elasticnet_model , elasticnet_intercept, elasticnet_coef, elasticnet_y_pred = elasticnet.fit_predict(ElasticNet(alpha=0.1, l1_ratio=1e-10, random_state=0), StandardScaler())
elasticnet_model , elasticnet_intercept, elasticnet_coef, elasticnet_y_pred
# Out:
# (Pipeline(steps=[('scaler', StandardScaler()),
#                  ('regressor',
#                   ElasticNet(alpha=0.1, l1_ratio=1e-10, random_state=0))]),
#  8577.538858195212,
#  array([ 1.29237064e+01, -2.26506269e+01, -1.52384032e+00,  8.19537559e+00,
#         17591.41253421, 17620.33460961, 17388.33441156, 17346.53909513,
#         17324.85334533, 17321.53255735, 17223.94882784, 17140.5609834 ,
#         17169.5099156 , 17123.87215022, 17126.30473717]))

# %%
# plot coefficients
elasticnet.plot_coeff('ElasticNet')

# %% [markdown]
# ## Model Comparison

# %%
# compare model coefficients
coef_df = pd.DataFrame({
    'LR': lr_coef,
    'Lasso': lasso_coef,
    'Ridge': ridge_coef,
    'ElasticNet': elasticnet_coef
}, index = feature_names)

coef_df
# Out:
#             LR    Lasso    Ridge  ElasticNet
# OC   -8,811.46    47.62   -66.23       12.92
# HC     -226.80  -176.01   -17.94      -22.65
# GAP  -7,788.62     0.00   -60.24       -1.52
# RET  12,335.04     0.00    88.59        8.20
# RET3  3,312.31     0.00    67.64        1.98
# MA3   1,058.62   873.49    66.07       34.86
# OC3  -2,879.45    -0.00   -65.61      -15.45
# HC3    -481.03  -625.60   -39.09      -48.25
# GAP3 -2,013.17   195.71   -24.70       29.13
# STD3   -339.59  -351.94   -25.67      -24.54
# UB3   7,604.80 7,597.62 2,116.86    1,922.84

# %%
# compare evaluation metrics
eval_df = pd.DataFrame({
    'LR': lr.eval_metrics(lr_model, lr_y_pred),
    'Lasso': lasso.eval_metrics(lasso_model, lasso_y_pred),
    'Ridge': ridge.eval_metrics(ridge_model, ridge_y_pred),
    'ElasticNet': elasticnet.eval_metrics(elasticnet_model, elasticnet_y_pred)
}, index = ['MSE', 'RMSE', 'R2_train', 'R2_test'])

eval_df
# Out:
#                 LR     Lasso     Ridge  ElasticNet
# MSE      43,522.39 44,233.81 43,443.58  593,043.05
# RMSE        208.62    210.32    208.43      770.09
# R2_train      1.00      1.00      1.00        0.99
# R2_test       0.98      0.98      0.98        0.76

# %%
X
# Out:
#               OC   HC   GAP   RET  RET3  MA3   OC3  HC3  GAP3  STD3       UB3
# 05/01/2012  0.00 0.01 -0.00  0.00  0.02 1.00  0.00 0.01  0.00  0.02  4,772.87
# 06/01/2012  0.01 0.02 -0.01  0.00 -0.00 1.00  0.00 0.01 -0.00  0.00  4,756.21
# 09/01/2012 -0.00 0.01 -0.00 -0.00 -0.00 1.00  0.00 0.02 -0.00  0.00  4,760.38
# 10/01/2012  0.02 0.02  0.01  0.02  0.02 1.01  0.01 0.02 -0.00  0.01  4,899.44
# 11/01/2012 -0.00 0.01  0.00  0.00  0.02 1.01  0.00 0.01  0.00  0.01  4,948.11
# ...          ...  ...   ...   ...   ...  ...   ...  ...   ...   ...       ...
# 23/12/2022 -0.01 0.02 -0.01 -0.02 -0.03 0.99 -0.01 0.02 -0.00  0.01 18,462.19
# 26/12/2022  0.01 0.02  0.00  0.01 -0.01 1.00 -0.00 0.02 -0.00  0.01 18,308.13
# 27/12/2022  0.00 0.01  0.00  0.01  0.00 1.01  0.00 0.01 -0.00  0.02 18,314.20
# 28/12/2022  0.00 0.01 -0.00 -0.00  0.02 1.00  0.00 0.01  0.00  0.01 18,220.42
# 29/12/2022  0.01 0.01 -0.00  0.00  0.01 1.00  0.00 0.01 -0.00  0.00 18,222.69
#
# [2715 rows x 11 columns]
