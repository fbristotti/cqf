# %% [markdown]
# ## Table of Contents
# * [First Bullet Head](#first-bullet)

# %% [markdown]
# ## First Bullet Header <a class="anchor" id="first-bullet"></a>

# %%
import pandas as pd

import yfinance as yf

# %%
df1 = yf.download('PETR4.SA', period='5d', progress=False)

# %%
df1
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2023-02-06 00:00:00-03:00  24.870001  25.870001  24.750000  25.780001
# 2023-02-07 00:00:00-03:00  25.910000  26.139999  25.459999  25.620001
# 2023-02-08 00:00:00-03:00  25.799999  26.150000  25.559999  26.049999
# 2023-02-09 00:00:00-03:00  26.049999  26.320000  25.790001  25.930000
# 2023-02-10 00:00:00-03:00  25.980000  26.790001  25.930000  26.719999
#
#                            Adj Close    Volume
# Date
# 2023-02-06 00:00:00-03:00  25.780001  82794500
# 2023-02-07 00:00:00-03:00  25.620001  55311800
# 2023-02-08 00:00:00-03:00  26.049999  48713100
# 2023-02-09 00:00:00-03:00  25.930000  38198300
# 2023-02-10 00:00:00-03:00  26.719999  54683100

# %%
df6 = yf.download('SPY', period='5d', interval='15m', progress=False)

# %%
df6
# Out:
#                                  Open        High         Low       Close  \
# Datetime
# 2023-02-06 09:30:00-05:00  410.250000  410.890015  409.364990  409.629913
# 2023-02-06 09:45:00-05:00  409.630005  410.559998  409.480011  410.290009
# 2023-02-06 10:00:00-05:00  410.320007  410.688995  409.679993  409.820007
# 2023-02-06 10:15:00-05:00  409.790009  409.839996  408.580505  408.739990
# 2023-02-06 10:30:00-05:00  408.739899  409.244995  408.100006  409.010010
# ...                               ...         ...         ...         ...
# 2023-02-10 15:00:00-05:00  407.649994  407.809998  407.148010  407.290009
# 2023-02-10 15:15:00-05:00  407.279999  407.399994  406.730011  407.140015
# 2023-02-10 15:30:00-05:00  407.144012  407.910004  407.130005  407.750000
# 2023-02-10 15:45:00-05:00  407.750000  408.440002  407.649994  408.040009
# 2023-02-10 16:00:00-05:00  408.040009  408.040009  408.040009  408.040009
#
#                             Adj Close   Volume
# Datetime
# ...

# %%
ticker = yf.Ticker('PBR')
options = ticker.option_chain('2023-02-17')
options
# Out:
# Options(calls=        contractSymbol             lastTradeDate  strike  lastPrice   bid  \
# 0   PBR230217C00003000 2023-02-01 16:47:24+00:00     3.0       8.25  8.25
# 1   PBR230217C00005000 2023-02-10 20:59:14+00:00     5.0       6.79  6.25
# 2   PBR230217C00006000 2023-01-31 15:14:23+00:00     6.0       5.34  5.45
# 3   PBR230217C00007000 2023-02-10 20:15:37+00:00     7.0       4.51  4.45
# 4   PBR230217C00008000 2023-02-10 20:32:13+00:00     8.0       3.50  3.45
# 5   PBR230217C00009000 2023-02-10 19:22:15+00:00     9.0       2.46  2.30
# 6   PBR230217C00009500 2023-02-10 17:51:53+00:00     9.5       1.90  1.81
# 7   PBR230217C00010000 2023-02-10 20:11:52+00:00    10.0       1.55  1.47
# 8   PBR230217C00010500 2023-02-10 20:28:34+00:00    10.5       1.05  1.03
# 9   PBR230217C00011000 2023-02-10 20:57:37+00:00    11.0       0.61  0.60
# 10  PBR230217C00011500 2023-02-10 20:59:25+00:00    11.5       0.28  0.28
# ...

# %%
options
# Out:
# Options(calls=        contractSymbol             lastTradeDate  strike  lastPrice   bid  \
# 0   PBR230217C00003000 2023-02-01 16:47:24+00:00     3.0       8.25  8.25
# 1   PBR230217C00005000 2023-02-10 20:59:14+00:00     5.0       6.79  6.25
# 2   PBR230217C00006000 2023-01-31 15:14:23+00:00     6.0       5.34  5.45
# 3   PBR230217C00007000 2023-02-10 20:15:37+00:00     7.0       4.51  4.45
# 4   PBR230217C00008000 2023-02-10 20:32:13+00:00     8.0       3.50  3.45
# 5   PBR230217C00009000 2023-02-10 19:22:15+00:00     9.0       2.46  2.30
# 6   PBR230217C00009500 2023-02-10 17:51:53+00:00     9.5       1.90  1.81
# 7   PBR230217C00010000 2023-02-10 20:11:52+00:00    10.0       1.55  1.47
# 8   PBR230217C00010500 2023-02-10 20:28:34+00:00    10.5       1.05  1.03
# 9   PBR230217C00011000 2023-02-10 20:57:37+00:00    11.0       0.61  0.60
# 10  PBR230217C00011500 2023-02-10 20:59:25+00:00    11.5       0.28  0.28
# ...

# %%
nifty50 = pd.read_html('https://en.wikipedia.org/wiki/NIFTY_50')[1]
nifty50
# Out:
#                        Company Name      Symbol              Sector[15]
# 0                 Adani Enterprises    ADANIENT             Diversified
# 1                 Adani Ports & SEZ  ADANIPORTS          Infrastructure
# 2                  Apollo Hospitals  APOLLOHOSP              Healthcare
# 3                      Asian Paints  ASIANPAINT       Consumer Durables
# 4                         Axis Bank    AXISBANK                 Banking
# 5                        Bajaj Auto  BAJAJ-AUTO              Automobile
# 6                     Bajaj Finance  BAJFINANCE      Financial Services
# 7                     Bajaj Finserv  BAJAJFINSV      Financial Services
# 8                     Bharti Airtel  BHARTIARTL       Telecommunication
# 9                  Bharat Petroleum        BPCL      Energy - Oil & Gas
# 10             Britannia Industries   BRITANNIA          Consumer Goods
# 11                            Cipla       CIPLA         Pharmaceuticals
# ...

# %%
query = pd.read_html('https://www.b3.com.br/pt_br/market-data-e-indices/indices/indices-amplos/indice-ibovespa-ibovespa-composicao-da-carteira.htm')
query
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\fbris\src\cqf\pylab\financial_time_series\lab_fin_time_series.ipynb Cell 11 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/fbris/src/cqf/pylab/financial_time_series/lab_fin_time_series.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> query = pd.read_html('https://www.b3.com.br/pt_br/market-data-e-indices/indices/indices-amplos/indice-ibovespa-ibovespa-composicao-da-carteira.htm')
#       <a href='vscode-notebook-cell:/c%3A/Users/fbris/src/cqf/pylab/financial_time_series/lab_fin_time_series.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a> query
#
# File c:\Users\fbris\anaconda3\envs\eqderivs\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
# ...
